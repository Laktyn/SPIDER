# %%
import spectral_analysis as sa

shear = sa.find_shear(sheared_spectrum = "data/sheared.csv",
            not_sheared_spectrum = "data/not_sheared.csv")

phase = sa.spider(phase_spectrum = "data/p_spectrum.csv",
            temporal_spectrum = "data/t_spectrum.csv",
            shear = shear)
